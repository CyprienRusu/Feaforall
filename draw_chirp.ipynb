# %%
from scipy.signal import chirp
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.fftpack import ifft
# %matplotlib inline

# %%
t = np.arange(0, 7e-5, step=2e-7)
f1 = 1e6
t1 = 7e-5
f0 = 2e6

# %%
ch = chirp(t,f0,t1,f1)

# %%
chart1 = plt.plot(t,ch)
plt.xlabel('Time t')
plt.ylabel('Chirp(Hz)')
plt.axis([0,7e-5,-1,1])
#plt.xticks(np.arange(0, 7e-5, step=2e-5))
#plt.yticks(np.arange(-8e4, 8e4, step=4e4))
plt.show()

# %%
tch = ifft(ch)

# %%
chart1 = plt.plot(t.real,tch.real)
plt.xlabel('Time t')
plt.ylabel('Chirp(Time)')
plt.axis([0,3.5e-5,-0.1,0.1])
#plt.xticks(np.arange(0, 7e-5, step=2e-5))
#plt.yticks(np.arange(-8e4, 8e4, step=4e4))
plt.show()

# %%
Tchirp = pd.DataFrame(tch.real,t.real)

# %%
Tchirp = Tchirp[:3.5e-5]

# %%
Tchirp.to_csv('chirp.dat',sep=" ",header=False)
